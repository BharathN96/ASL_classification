# %% [markdown]
# # ASL Classification

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        validation_split=0.2)

# %%
train_generator = train_datagen.flow_from_directory(
        'Alphabets/Alphabets/',
        target_size=(250, 250),
        batch_size=5,
        class_mode='categorical',
        subset='training')
# Out:
# Found 519 images belonging to 26 classes.

# %%
val_generator = train_datagen.flow_from_directory(
        'Alphabets/Alphabets/',
        target_size=(250, 250),
        batch_size=5,
        class_mode='categorical',
        subset='validation')
# Out:
# Found 129 images belonging to 26 classes.

# %%
plt.figure(figsize=(60,60))
ax=0
for i in range(10):
    j=np.random.randint(low=0,high=17)
    k=np.random.randint(low=0,high=5)
    ax=plt.subplot(10,1,(i+1))
    ax.imshow(train_generator[j][0][k])
    ax.title.set_text(train_generator[j][1][k])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Dropout,Flatten

# %%
cnn=Sequential()


cnn.add(Conv2D(32,(3,3),activation='relu'))
cnn.add(MaxPooling2D((2,2)))

cnn.add(Dropout(0.2))

cnn.add(Flatten())

cnn.add(Dense(64,activation='relu'))

cnn.add(Dense(26,activation='softmax'))

# %%
cnn.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model1=cnn.fit_generator(train_generator,
                        steps_per_epoch=512//5,
                         epochs=5,
                         validation_data=val_generator,
                         validation_steps=129//5)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 102 steps, validate for 25 steps
# Epoch 1/5
# 102/102 [==============================] - 39s 385ms/step - loss: 6.1566 - accuracy: 0.0393 - val_loss: 3.2582 - val_accuracy: 0.0320
# Epoch 2/5
# 102/102 [==============================] - 40s 392ms/step - loss: 3.2590 - accuracy: 0.0275 - val_loss: 3.2582 - val_accuracy: 0.0400
# Epoch 3/5
# 102/102 [==============================] - 40s 394ms/step - loss: 3.2590 - accuracy: 0.0255 - val_loss: 3.2581 - val_accuracy: 0.0400
# Epoch 4/5
# 102/102 [==============================] - 40s 393ms/step - loss: 3.2589 - accuracy: 0.0334 - val_loss: 3.2581 - val_accuracy: 0.0400
# Epoch 5/5
# 102/102 [==============================] - 40s 392ms/step - loss: 3.2588 - accuracy: 0.0373 - val_loss: 3.2581 - val_accuracy: 0.0400

# %%
from tensorflow.keras.applications.mobilenet_v2

from tensorflow.keras.applications.densenet

# %%
import tensorflow

# %%
tensorflow.__version__
# Out:
# '2.1.0'

# %%
#! pip install split-folders
#Downgrade it to 0.3.1

#split_folders.ratio('Mushrooms', output="output", seed=1337, ratio=(.8,.2))
